# %%
#import libray function
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("/content/DAnalysis.csv")
df.head(5)
# Out:
#    Age Gender Educational_Status Professional_Status Marital_Status Location  \
# 0   22   Male        BSc Student          Unemployed      Unmarried     City
# 1   24   Male        BSc Student          Unemployed      Unmarried     City
# 2   24   Male        BSc Student          Unemployed      Unmarried     City
# 3   22   Male        BSc Student          Unemployed       Divorced  Village
# 4   22   Male        BSc Student          Unemployed      Unmarried  Village
#
#   Live_With Debt   Exercise Smoke  ...    Illness Sleep_Time Work_Pressure  \
# 0    Family   No      Never    No  ...         No    7 hours            No
# 1    Family   No  Sometimes    No  ...  Sometimes    7 hours           Yes
# 2    Family   No  Sometimes   Yes  ...  Sometimes    5 hours      Moderate
# 3    Family  Yes      Never   Yes  ...         No    7 hours           Yes
# 4    Friend   No  Sometimes    No  ...        Yes    6 hours      Moderate
#
# ...

# %%
df.isnull().sum()
# Out:
# Age                    0
# Gender                 0
# Educational_Status     0
# Professional_Status    0
# Marital_Status         0
# Location               0
# Live_With              0
# Debt                   0
# Exercise               0
# Smoke                  0
# Drink                  0
# Illness                0
# Sleep_Time             0
# Work_Pressure          0
# Eating_Disorder        0
# Cheated                0
# Mistreated             0
# Suicidal               0
# Lost                   0
# Prayer                 0
# Depressed              0
# dtype: int64

# %%
df.head()
# Out:
#    Age Gender Educational_Status Professional_Status Marital_Status Location  \
# 0   22   Male        BSc Student          Unemployed      Unmarried     City
# 1   24   Male        BSc Student          Unemployed      Unmarried     City
# 2   24   Male        BSc Student          Unemployed      Unmarried     City
# 3   22   Male        BSc Student          Unemployed       Divorced  Village
# 4   22   Male        BSc Student          Unemployed      Unmarried  Village
#
#   Live_With Debt   Exercise Smoke  ...    Illness Sleep_Time Work_Pressure  \
# 0    Family   No      Never    No  ...         No    7 hours            No
# 1    Family   No  Sometimes    No  ...  Sometimes    7 hours           Yes
# 2    Family   No  Sometimes   Yes  ...  Sometimes    5 hours      Moderate
# 3    Family  Yes      Never   Yes  ...         No    7 hours           Yes
# 4    Friend   No  Sometimes    No  ...        Yes    6 hours      Moderate
#
# ...

# %%
df.shape
# Out:
# (48, 21)

# %% [markdown]
# ## lebel Encoding

# %%
#label encoding is used for output column only

from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['Gender']= le.fit_transform(df['Gender'])
df['Educational_Status']= le.fit_transform(df['Educational_Status'])
df['Professional_Status']= le.fit_transform(df['Professional_Status'])
df['Marital_Status']= le.fit_transform(df['Marital_Status'])
df['Location']= le.fit_transform(df['Location'])
df['Live_With']= le.fit_transform(df['Live_With'])
df['Debt']= le.fit_transform(df['Debt'])
df['Exercise']= le.fit_transform(df['Exercise'])
df['Smoke']= le.fit_transform(df['Smoke'])
df['Illness']= le.fit_transform(df['Illness'])
df['Sleep_Time']= le.fit_transform(df['Sleep_Time'])
df['Work_Pressure']= le.fit_transform(df['Work_Pressure'])
df['Eating_Disorder']= le.fit_transform(df['Eating_Disorder'])
df['Cheated']= le.fit_transform(df['Cheated'])
df['Mistreated']= le.fit_transform(df['Mistreated'])
df['Suicidal']= le.fit_transform(df['Suicidal'])
df['Lost']= le.fit_transform(df['Lost'])
df['Prayer']= le.fit_transform(df['Prayer'])
df['Depressed']= le.fit_transform(df['Depressed'])
df['Drink']= le.fit_transform(df['Drink'])

# %%
le.classes_
# Out:
# array(['No', 'Sometimes', 'Yes'], dtype=object)

# %%
df.head()
# Out:
#    Age  Gender  Educational_Status  Professional_Status  Marital_Status  \
# 0   22       1                   0                    1               2
# 1   24       1                   0                    1               2
# 2   24       1                   0                    1               2
# 3   22       1                   0                    1               0
# 4   22       1                   0                    1               2
#
#    Location  Live_With  Debt  Exercise  Smoke  ...  Illness  Sleep_Time  \
# 0         0          1     0         1      0  ...        0           3
# 1         0          1     0         2      0  ...        1           3
# 2         0          1     0         2      2  ...        1           1
# 3         1          1     1         1      2  ...        0           3
# 4         1          2     0         2      0  ...        2           2
#
#    Work_Pressure  Eating_Disorder  Cheated  Mistreated  Suicidal  Lost  \
# ...

# %%
correlation_matrix = df.corr()
plt.figure(figsize=(8, 5))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# %%
df.corr()
# Out:
#                           Age    Gender  Professional_Status  Marital_Status  \
# Age                  1.000000  0.095065             0.173748   -1.924775e-02
# Gender               0.095065  1.000000            -0.053838    8.548672e-02
# Professional_Status  0.173748 -0.053838             1.000000   -8.876154e-02
# Marital_Status      -0.019248  0.085487            -0.088762    1.000000e+00
# Location            -0.164658  0.115470             0.093250   -6.345743e-02
# Live_With            0.036018  0.048970             0.039547    8.073584e-02
# Debt                -0.065727  0.165683            -0.095572   -3.512026e-01
# Exercise             0.035870  0.010621            -0.128657    1.108989e-01
# Smoke                0.244695  0.191785             0.154881   -7.459658e-17
# Drink               -0.065799  0.125245             0.101144    6.882925e-02
# Illness             -0.041107 -0.182574             0.147442    1.003350e-01
# ...

# %%
#drop one feature
df=df.drop(['Educational_Status'], axis = 1)

# %%
df.shape
# Out:
# (48, 20)

# %%
#deside the input feature
x = df.drop(['Depressed'], axis = 1)

# %%
x.head()
# Out:
#    Age  Gender  Professional_Status  Marital_Status  Location  Live_With  \
# 0   22       1                    1               2         0          1
# 1   24       1                    1               2         0          1
# 2   24       1                    1               2         0          1
# 3   22       1                    1               0         1          1
# 4   22       1                    1               2         1          2
#
#    Debt  Exercise  Smoke  Drink  Illness  Sleep_Time  Work_Pressure  \
# 0     0         1      0      0        0           3              1
# 1     0         2      0      0        1           3              2
# 2     0         2      2      1        1           1              0
# 3     1         1      2      1        0           3              2
# 4     0         2      0      0        2           2              0
#
#    Eating_Disorder  Cheated  Mistreated  Suicidal  Lost  Prayer
# ...

# %%
#deside the ouput feature
y = df['Depressed']

# %%
y
# Out:
# 0     1
# 1     2
# 2     0
# 3     2
# 4     0
# 5     0
# 6     0
# 7     1
# 8     1
# 9     0
# 10    2
# 11    1
# 12    1
# 13    1
# 14    0
# 15    2
# 16    1
# 17    2
# 18    2
# 19    1
# 20    0
# 21    0
# 22    1
# 23    1
# 24    2
# 25    2
# 26    1
# 27    2
# 28    1
# 29    1
# 30    1
# 31    0
# 32    2
# 33    1
# 34    1
# 35    1
# 36    1
# 37    1
# 38    2
# 39    1
# 40    1
# 41    1
# 42    2
# 43    2
# 44    2
# 45    2
# 46    1
# 47    1
# Name: Depressed, dtype: int64

# %%
#train test split from the dataset
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest= train_test_split(x,y,test_size=.3,random_state=1)

# %% [markdown]
# ## Logistic regration

# %%
#import logistic regration algorithm
from sklearn.linear_model import LogisticRegression

# %%
logmodel = LogisticRegression()
logmodel.fit(xtrain,ytrain)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
logmodel.score(xtest,ytest)
# Out:
# 1.0

# %%
predictions = logmodel.predict(xtest)

# %%
predictions
# Out:
# array([1, 1, 2, 1, 0, 2, 0, 1, 2, 2, 1, 1, 0, 1, 1])

# %%
from sklearn.metrics import classification_report

# %%
ytest.shape
# Out:
# (15,)

# %%
print(classification_report(ytest,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         3
#            1       1.00      1.00      1.00         8
#            2       1.00      1.00      1.00         4
#
#     accuracy                           1.00        15
#    macro avg       1.00      1.00      1.00        15
# weighted avg       1.00      1.00      1.00        15

# %% [markdown]
# ## random forest

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=5)
rf.fit(xtrain,ytrain)
# Out:
# RandomForestClassifier(n_estimators=5)

# %%
pred6 = rf.predict(xtest)

# %%
print(rf.score(xtest,ytest))
# Out:
# 1.0

# %%
from sklearn.metrics import classification_report,confusion_matrix
print(confusion_matrix(ytest,pred6))
print(classification_report(ytest,pred6))
# Out:
# [[3 0 0]
#  [2 6 0]
#  [1 1 2]]
#               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67         3
#            1       0.86      0.75      0.80         8
#            2       1.00      0.50      0.67         4
#
#     accuracy                           0.73        15
#    macro avg       0.79      0.75      0.71        15
# weighted avg       0.82      0.73      0.74        15

# %% [markdown]
# ## KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(xtrain,ytrain)
# Out:
# KNeighborsClassifier()

# %%
pred4 = knn.predict(xtest)

# %%
print(knn.score(xtest,ytest))
# Out:
# 0.7333333333333333

# %%
from sklearn.metrics import classification_report,confusion_matrix
print(confusion_matrix(ytest,pred4))
print(classification_report(ytest,pred4))
# Out:
# [[1 2 0]
#  [0 8 0]
#  [0 2 2]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.33      0.50         3
#            1       0.67      1.00      0.80         8
#            2       1.00      0.50      0.67         4
#
#     accuracy                           0.73        15
#    macro avg       0.89      0.61      0.66        15
# weighted avg       0.82      0.73      0.70        15

# %% [markdown]
# ## DT

# %%
#Decision Tree Classifier

from sklearn.tree import DecisionTreeClassifier
dtree = DecisionTreeClassifier() #training
dtree.fit(xtrain,ytrain)
# Out:
# DecisionTreeClassifier()

# %%
pred3 = dtree.predict(xtest)

# %%
print(dtree.score(xtest,ytest))
# Out:
# 0.8666666666666667

# %%
from sklearn.metrics import classification_report,confusion_matrix
print(confusion_matrix(ytest,pred3))
print(classification_report(ytest,pred3))
# Out:
# [[2 1 0]
#  [0 8 0]
#  [0 1 3]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.67      0.80         3
#            1       0.80      1.00      0.89         8
#            2       1.00      0.75      0.86         4
#
#     accuracy                           0.87        15
#    macro avg       0.93      0.81      0.85        15
# weighted avg       0.89      0.87      0.86        15
